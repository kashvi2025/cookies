# %%
#I STARTED WITH QUESTION 2 BECAUSE I HAD ISSUES WITH THE TXT FILE for #1. it isn't uploading correctly but I attempted a possible soln

import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
planets = sns.load_dataset('planets')

# %%
planets = planets_df.dropna()

# %%
sns.scatterplot(data=planets, x='orbital_period', y='mass', hue='method')
plt.title('Orbit vs Mass of Exoplanets')
plt.xlabel('Orbit in days')
plt.ylabel('Mass')
plt.legend(title='Method')
plt.show()

# %%
discoveries = planets.groupby(['year', 'method']).size().unstack()
discoveries.plot(kind='bar', stacked=True)
plt.title('Exoplanet Discoveries by Year and Method')
plt.xlabel('year')
plt.ylabel('Exoplanets discovered')
plt.legend(title='method')
plt.show()

# %%
tweets = pd.read_csv('AOC_recent_tweets.txt', index='id')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 tweets = pd.read_csv('AOC_recent_tweets.txt', index='id')
#
# TypeError: read_csv() got an unexpected keyword argument 'index'

# %%
tweets.head()

# %%
def hours(col):
    hourss = col.dt.hour
    mins = col.dt.minute
    sec = col.dt.second
    decihours = hours+(mins/60) + (sec/3600)
    return decihours

# %%
tweets['hours'] = hours(pd.to_datetime(tweets['created at']))

# %%
colss = ['created at', 'hours', 'full text']
df = tweets[colss]
